# %% [markdown]
# <a href="https://colab.research.google.com/github/ByAnAlex/Scientific-Computer/blob/main/Sesi_5_SC_LAB_Bryan.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('seaborn-v0_8-poster')
# %matplotlib inline

# %%
# step size
h = 0.1
# define grid
x = np.arange(0, 2*np.pi, h)
# compute function
y = np.cos(x)

# compute vector of forward differences
forward_diff = np.diff(y)/h
# compute corresponding grid
x_diff = x[:-1]
# compute exact solution
exact_solution = -np.sin(x_diff)

# Plot solution
plt.figure(figsize = (12, 8))
plt.plot(x_diff, forward_diff, '--', \
         label = 'Finite difference approximation')
plt.plot(x_diff, exact_solution, \
         label = 'Exact solution')
plt.legend()
plt.show()

# Compute max error between
# numerical derivative and exact solution
max_error = max(abs(exact_solution - forward_diff))
print(max_error)
# Out:
# 0.049984407218554114

# %%
# Backward Difference Method

backward_diff = (y[1:] - y[:-1]) / h
x_diff_back = x[1:]
exact_solution_back = -np.sin(x_diff_back)

plt.figure(figsize=(12, 8))
plt.plot(x_diff_back, backward_diff, '--', label='Backward difference approximation')
plt.plot(x_diff_back, exact_solution_back, label='Exact solution')
plt.legend()
plt.show()

max_error_back = max(abs(exact_solution_back - backward_diff))
print(max_error_back)
# Out:
# 0.04997039864231646

# %%
#Computing Integral
#Riemann Integral

a = 0
b = np.pi
n = 11
h = ( b - a ) / ( n - 1)
x = np.linspace(a, b, n)
f = np.sin(x)

I_riemannL = h * sum(f[:n-1])
err_riemannL = 2 - I_riemannL

I_riemannR = h * sum(f[1::])
err_riemannR = 2 - I_riemannR

I_mid = h * sum(np.sin((x[:n-1]+ x[1:])/2))
err_mid  = 2 - I_mid

print(I_riemannL)
print(err_riemannL)
print(I_riemannR)
print(err_riemannR)
print(I_mid)
print(err_mid)
# Out:
# 1.9835235375094546
# 0.01647646249054535
# 1.9835235375094546
# 0.01647646249054535
# 2.0082484079079745
# -0.008248407907974542

# %%
#Trapezoid Rule

a = 0
b = np.pi
n = 11
h = ( b - a ) / ( n - 1)
x = np.linspace( a, b, n)
f = np.sin(x)

I_trap = (h/2)*(f[0]+ \
          2 * sum(f[1:n-1])+f[n-1])
err_trap = 2 - I_trap

print(I_trap)
print(err_trap)
# Out:
# 1.9835235375094546
# 0.01647646249054535

# %%
#Simpson Rule

import numpy as np

a = 0
b = np.pi
n = 11
h = (b - a) / (n - 1)
x = np.linspace(a, b, n)
f = np.sin(x)


I_simp = (h / 3) * (f[0] +
                    4 * sum(f[1:n-1:2]) +
                    2 * sum(f[2:n-2:2]) +
                    f[n-1])
err_simp = 2 - I_simp


print(I_simp)
print(err_simp)
# Out:
# 2.0001095173150043
# -0.00010951731500430384

# %%
import numpy as np


a = 0
b = np.pi
n = 11
h = (b - a) / (n - 1)
x = np.linspace(a, b, n)
f = np.sin(x)


I_trapz = np.trapz(f, x)

I_trap = (h / 2) * (f[0] + 2 * sum(f[1:n-1]) + f[n-1])

print(I_trapz)
print(I_trap)
# Out:
# 1.9835235375094544
# 1.9835235375094546
# <ipython-input-15-2ded860a3ef7>:12: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   I_trapz = np.trapz(f, x)

# %%
from scipy.integrate import quad
I_quad, est_err_quad = quad(np.sin, 0, np.pi)
print(I_quad)
err_quad = 2 - I_quad
print(est_err_quad)
# Out:
# 2.0
# 2.220446049250313e-14
